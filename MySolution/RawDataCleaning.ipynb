# %%
import os.path
import json
import pandas as pd
import numpy as np

import re #regular expression matching

# %%
def raw_data_cleanup(filename):
    """
    load rawdata.json and do basic cleanup
    -enter filename with extension as str, file should be in subdirectory raw_data
    
    param: filename, str
    return: DataFrame
    """
    PATH = "./" + str(filename)
    
    if os.path.isfile(PATH):
        print("{} is located in current directory".format(filename))

        with open(PATH) as json_file:  
            data = [json.loads(line) for line in json_file]
        df = pd.DataFrame(data,columns = ['date','location','category','keyword'])
        print("{} is imported into dataframe".format(filename))

        # Generate city column from location 
        city_list = []
        for i in df['location']:
            if ',' in i:
                city = i.split(',')[0]
                city_list.append(city)
            else:
                city_list.append(i)
        df['city'] = city_list

        # Datetime transformation
        
        # Check Top places (location) where news are coming from
        city_sort = df['city'].groupby(df['city']).count().sort_values(ascending=False)
        display(city_sort)
        
        # Save DataFrame into csv file
        display(df)
        city_sort.to_csv('./city_sort.csv', index = False)
        df.to_csv('./output.csv', index = False)
        
    else:
        print("{} does not exist in directory. Function was not complete.".format(filename))
    
    return

# %%
raw_data_cleanup('rawdata.json')
# Out:
# rawdata.json is located in current directory
# rawdata.json is imported into dataframe
# city
# LOSANGELES          9
# ROHNERTPARK         8
# NEWYORK             7
# PETALUMA            5
# EMERYVILLE          5
# MIAMI               5
# AUSTIN              3
# IRVINE              3
# ATLANTA             3
# SANFRANCISCO        3
# HOLLYWOOD           3
# SYDNEY              3
# GREENVILLE          2
# SANDIEGO            2
# SANRAMON            2
# SHENZHEN            2
# CHICAGO             2
# QUINCY              2
# VANCOUVER           2
# LOUISVILLE          1
# GAINESVILLE         1
# GARLAND             1
# GEORGETOWN          1
# MEMPHIS             1
# MADISON             1
# HAMMOND             1
# JACKSONVILLE        1
# IRVING              1
# LILLINGTON          1
# HONGKONG            1
#                    ..
# WESTPALMBEACH       1
# WHITBY              1
# WICHITA             1
# WILMINGTON          1
# SANANTONIO          1
# RICHMOND            1
# NAPLES              1
# RENO                1
# NEWHAVEN            1
# NEWORLEANS          1
# WISCONSINDELLS      1
# NORTHADAMS          1
# NORTHBORO           1
# OKLAHOMACITY        1
# OLYMPIA             1
# ORLANDO             1
# OTTUMWA             1
# PALMBEACHGARDENS    1
# PASADENA            1
# PHILADELPHIA        1
# PHOENIX             1
# PITTSBURG           1
# PLAYAVISTA          1
# PLEASANTON          1
# POLAND              1
# PORTLAND            1
# PRAGUE              1
# QUAKERTOWN          1
# RALEIGH             1
# ALLEN               1
# Name: city, Length: 108, dtype: int64
#                     date                   location  \
# 0     8-3-2018-19:54-CDT               HAMMOND, La.
# 1     8-3-2018-06:00-EDT                     SYDNEY
# 2     8-3-2018-05:00-PDT         EMERYVILLE, Calif.
# 3     8-3-2018-05:00-PDT           SANRAMON, Calif.
# 4     8-3-2018-05:00-PDT        ROHNERTPARK, Calif.
# 5     8-3-2018-08:00-EDT                    ATLANTA
# 6     8-3-2018-08:00-EDT             ANDERSON, Ind.
# 7     8-3-2018-07:00-PDT                 LOSANGELES
# 8     8-3-2018-07:00-PDT                 LOSANGELES
# 9     8-3-2018-10:22-EDT               APOPKA, Fla.
# 10    8-3-2018-11:00-EDT           WILMINGTON, Del.
# 11    8-3-2018-11:00-CDT                 NEWORLEANS
# 12    8-3-2018-09:00-PDT         PLEASANTON, Calif.
# 13    8-3-2018-12:00-EDT                    SEATTLE
# 14    8-3-2018-09:00-PDT                   SANDIEGO
# 15    8-3-2018-10:00-PDT           PETALUMA, Calif.
# 16    8-3-2018-13:00-EDT               POLAND, Ohio
# 17   8-2-2018-16:06-CEST                     PRAGUE
# 18    8-2-2018-08:00-PDT           PASADENA, Calif.
# 19    8-2-2018-11:31-EDT              ORLANDO, Fla.
# 20    8-2-2018-09:00-PDT             IRVINE, Calif.
# 21    8-2-2018-09:00-PDT            BELLEVUE, Wash.
# 22    8-2-2018-12:06-EDT               PHILADELPHIA
# 23    8-2-2018-12:40-EDT                    NEWYORK
# 24    8-2-2018-10:00-PDT        ROHNERTPARK, Calif.
# 25    8-2-2018-14:15-CDT          COOKEVILLE, Tenn.
# 26    8-2-2018-13:22-MDT            SANJOSE, Calif.
# 27    8-3-2018-12:29-EDT           CALGARY, Alberta
# 28    8-2-2018-15:54-EDT                  CLEVELAND
# 29    8-2-2018-16:00-EDT                 WAYNE, Pa.
# ..                   ...                        ...
# 130            7-30-2018             SOMERSET, N.J.
# 131            7-30-2018  GEORGETOWN, CaymanIslands
# 132            7-30-2018             MADISON, Wisc.
# 133            7-30-2018                   LASVEGAS
# 134            7-30-2018           BLOOMFIELD, N.J.
# 135            7-30-2018                 LOSANGELES
# 136            7-30-2018           PETALUMA, Calif.
# 137            7-30-2018        ROHNERTPARK, Calif.
# 138            7-30-2018          COACHELLA, Calif.
# 139            7-30-2018           SANRAMON, Calif.
# 140            7-30-2018          NORTHADAMS, Mass.
# 141            7-30-2018                  YORK, Pa.
# 142            7-30-2018        SHIJIAZHUANG, China
# 143            7-30-2018               NAPLES, Fla.
# 144            7-30-2018           LILLINGTON, N.C.
# 145            7-30-2018           CALEDONIA, Mich.
# 146            7-30-2018              OTTUMWA, Iowa
# 147            7-30-2018                      MIAMI
# 148            7-30-2018            PITTSBURG, Kan.
# 149            7-30-2018            DONGYING, China
# 150            7-30-2018                TAMPA, Fla.
# 151            7-30-2018                    NEWYORK
# 152            7-30-2018      SHELBURNEFALLS, Mass.
# 153            7-30-2018                     DENVER
# 154            7-30-2018                    NEWYORK
# 155            7-30-2018                 LOSANGELES
# 156            7-30-2018              RALEIGH, N.C.
# 157            7-30-2018           PETALUMA, Calif.
# 158            7-30-2018        ROHNERTPARK, Calif.
# 159            7-26-2018             FRESNO, Calif.
#
#                                category  \
# 0                           Franchising
# 1           Pharmaceuticals and Biotech
# 2           Financing and Student Loans
# 3             Active and Healthy Living
# 4                        Financial News
# 5                      Entrepreneurship
# 6          Agriculture and Horticulture
# 7                             Marketing
# 8             Active and Healthy Living
# 9                  Consumer Electronics
# 10          System and Data Integration
# 11                          Real Estate
# 12   Healthcare and Medical Informatics
# 13            Aeronautics and Aerospace
# 14                           Healthcare
# 15                     Entrepreneurship
# 16                           Healthcare
# 17              Client/Server Computing
# 18                      High Technology
# 19         Transportation and Logistics
# 20                            Education
# 21                    Retail Technology
# 22                 Business to Business
# 23                       Cryptocurrency
# 24          Financing and Student Loans
# 25            Colleges and Universities
# 26                            Marketing
# 27                              Finance
# 28      Restaurants, Bars, and Catering
# 29                           Accounting
# ..                                  ...
# 130                            Staffing
# 131                              Autism
# 132         Banking, Finance, Insurance
# 133       Exercise and Physical Fitness
# 134          Food and Beverage Services
# 135                             Finance
# 136                    Entrepreneurship
# 137                      Financial News
# 138              Arts and Entertainment
# 139           Active and Healthy Living
# 140              Arts and Entertainment
# 141              Computers and Software
# 142                         Electronics
# 143                               Books
# 144                               Books
# 145                               Books
# 146                               Books
# 147                Vacations and Travel
# 148                               Books
# 149                  Lamps and Lighting
# 150              Arts and Entertainment
# 151                          Archeology
# 152                  Hobbies and Crafts
# 153                         Multi-Media
# 154                             Theater
# 155             Sports-related Business
# 156     Sports, Fitness, and Recreation
# 157                    Entrepreneurship
# 158         Financing and Student Loans
# 159                         Video Games
#
#                                    keyword            city
# 0                                corporate         HAMMOND
# 1                  Animal Health Solutions          SYDNEY
# 2                          college tuition      EMERYVILLE
# 3                                  fitness        SANRAMON
# 4                           dying industry     ROHNERTPARK
# 5          African American Marketing firm         ATLANTA
# 6                               Biocontrol        ANDERSON
# 7                       adwords management      LOSANGELES
# 8                         active lifestyle      LOSANGELES
# 9                              apple watch          APOPKA
# 10                                     API      WILMINGTON
# 11                                   Cloud      NEWORLEANS
# 12                    Dispense Supplements      PLEASANTON
# 13                             3D printing         SEATTLE
# 14                     Alzheimer's disease        SANDIEGO
# 15                            company time        PETALUMA
# 16                                Clime Rd          POLAND
# 17                           cybersecurity          PRAGUE
# 18                              conference        PASADENA
# 19                                delivery         ORLANDO
# 20                     Colombian educators          IRVINE
# 21                             competition        BELLEVUE
# 22                                    8(a)    PHILADELPHIA
# 23                          alex mashinsky         NEWYORK
# 24                         family expenses     ROHNERTPARK
# 25                        anytime learning      COOKEVILLE
# 26               Advertising and Marketing         SANJOSE
# 27                          Canadian banks         CALGARY
# 28                            William Rini       CLEVELAND
# 29                      Business Solutions           WAYNE
# ..                                     ...             ...
# 130        Career Planning and Development        SOMERSET
# 131                                    ABA      GEORGETOWN
# 132                                Banking         MADISON
# 133                            BodyBuilder        LASVEGAS
# 134                 august restaurant week      BLOOMFIELD
# 135                                Altcoin      LOSANGELES
# 136                       entrepreneurship        PETALUMA
# 137                      financial trouble     ROHNERTPARK
# 138                       african american       COACHELLA
# 139                           eating right        SANRAMON
# 140                  community involvement      NORTHADAMS
# 141                          Accessibility            YORK
# 142                             Custom PCB    SHIJIAZHUANG
# 143                           "Our Family"          NAPLES
# 144     "Rose and Her Very Special Garden"      LILLINGTON
# 145             "Mommy and Me Don't Match"       CALEDONIA
# 146                              "Daddies"         OTTUMWA
# 147                               holidays           MIAMI
# 148  "The Tribulations of the Leprechauns"       PITTSBURG
# 149                       LED Street Light        DONGYING
# 150                         BOOKING-AGENCY           TAMPA
# 151                                ancient         NEWYORK
# 152                           cross stitch  SHELBURNEFALLS
# 153                              Bluetooth          DENVER
# 154         best new jukebox musicals 2018         NEWYORK
# 155           How to create business video      LOSANGELES
# 156                              adventure         RALEIGH
# 157                               employee        PETALUMA
# 158                  college affordability     ROHNERTPARK
# 159                                android          FRESNO
#
# [160 rows x 5 columns]
